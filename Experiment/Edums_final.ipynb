# %%
import cv2
import numpy as np
from scipy import ndimage
from scipy.ndimage import gaussian_filter
from skimage.metrics import structural_similarity as ssim

# %%
# #phương pháp bicubic"
# nameImg = "1"
# img = cv2.imread(f"{nameImg}.jpg")

# # resize bằng bicubic
# bicubic = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

# img1 = bicubic
# cv2.imwrite(f"{nameImg}_bicubic.jpg", img1)

# %%
# # EIAAF
# gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# # tính gradient
# gx = cv2.Sobel(gray, cv2.CV_32F, 1, 0)
# gy = cv2.Sobel(gray, cv2.CV_32F, 0, 1)

# mag = cv2.magnitude(gx, gy)
# dir = cv2.phase(gx, gy)

# # mờ theo hướng cạnh
# blur1 = cv2.GaussianBlur(img1, (5, 5), 0.5)
# mask = cv2.normalize(mag, None, 0, 1, cv2.NORM_MINMAX)

# # trộn
# mask = np.stack([mask] * 3, axis=-1)
# jaggy_suppressed = img1*(1-mask) + blur1*mask
# jaggy_suppressed = jaggy_suppressed.astype(np.uint8)
# img2 = jaggy_suppressed
# cv2.imwrite(f"{nameImg}_EIAAF.jpg", img2)

# %%
# EDUMS
def tinh_gradient(anh):
    sobel_x = np.array([[-1, 0, 1],
                        [-2, 0, 2],
                        [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1],
                        [ 0,  0,  0],
                        [ 1,  2,  1]])
    gx = ndimage.convolve(anh, sobel_x, mode='reflect')
    gy = ndimage.convolve(anh, sobel_y, mode='reflect')
    do_lon = np.sqrt(gx**2 + gy**2)
    huong = np.arctan2(gy, gx)
    return do_lon, huong, gx, gy

def rgb_to_ycbcr_fullrange(rgb):
    # rgb: float in 0..255
    R = rgb[...,0]; G = rgb[...,1]; B = rgb[...,2]
    Y  =  0.29900 * R + 0.58700 * G + 0.11400 * B
    Cb = 128.0 + (-0.168736 * R - 0.331264 * G + 0.5 * B)
    Cr = 128.0 + (0.5 * R - 0.418688 * G - 0.081312 * B)
    return Y, Cb, Cr

def ycbcr_to_rgb_fullrange(Y, Cb, Cr):
    cb = Cb - 128.0
    cr = Cr - 128.0
    R = Y + 1.40200 * cr
    G = Y - 0.344136 * cb - 0.714136 * cr
    B = Y + 1.77200 * cb
    return np.stack([R, G, B], axis=-1)

def edums_nhanh_ycbcr(anh, alpha=1.5, sigma=2.0, bgr=False, verbose=False):
    """
    Sharpen chỉ trên kênh Y (YCbCr full-range), giữ Cb/Cr nguyên vẹn.
    Trả về ảnh cùng dtype/scale như input. Nếu bgr=True thì input/output là BGR (cv2).
    Nếu verbose=True: in thông tin debug.
    """
    orig_dtype = anh.dtype
    arr = anh.astype(np.float64)

    # detect float 0..1 scaling
    scaled_from_0_1 = False
    if np.issubdtype(orig_dtype, np.floating) and arr.max() <= 1.0 + 1e-12:
        arr = arr * 255.0
        scaled_from_0_1 = True

    has_alpha = (arr.ndim == 3 and arr.shape[2] == 4)
    alpha_chan = None
    if has_alpha:
        alpha_chan = arr[...,3].copy()
        arr = arr[...,:3]

    if verbose:
        print("DEBUG: arr.shape", arr.shape, "dtype", orig_dtype, "scaled_from_0_1", scaled_from_0_1)

    # If grayscale input (HxW)
    if arr.ndim == 2:
        Y = arr
        do_lon, huong, gx, gy = tinh_gradient(Y)
        max_m = np.max(do_lon)
        do_lon_norm = do_lon / (max_m + 1e-10)
        w = np.clip(do_lon_norm, 0.0, 1.0)
        Y_blur = gaussian_filter(Y, sigma=sigma)
        mask = Y - Y_blur
        Y_sharp = np.clip(Y + alpha * mask * w, 0.0, 255.0)
        out = Y_sharp
    else:
        rgb = arr.copy()
        if bgr:
            rgb = rgb[..., ::-1]  # BGR -> RGB for processing

        # Convert to YCbCr (works with 0..255 float)
        Y, Cb, Cr = rgb_to_ycbcr_fullrange(rgb)

        # compute edge weight on Y
        do_lon, huong, gx, gy = tinh_gradient(Y)
        max_m = np.max(do_lon)
        do_lon_norm = do_lon / (max_m + 1e-10)
        w = np.clip(do_lon_norm, 0.0, 1.0)

        Y_blur = gaussian_filter(Y, sigma=sigma)
        mask = Y - Y_blur
        Y_sharp = np.clip(Y + alpha * mask * w, 0.0, 255.0)

        # Reconstruct RGB from sharpened Y and original Cb/Cr
        out_rgb = ycbcr_to_rgb_fullrange(Y_sharp, Cb, Cr)
        # Clip and ensure shape HxWx3
        out_rgb = np.clip(out_rgb, 0.0, 255.0)

        if bgr:
            out_rgb = out_rgb[..., ::-1]

        out = out_rgb

    # reattach alpha channel if present
    if has_alpha:
        alpha_chan_clipped = np.clip(alpha_chan, 0.0, 255.0)
        out = np.concatenate([out, alpha_chan_clipped[..., np.newaxis]], axis=2)

    # cast back to original dtype/scale
    if scaled_from_0_1:
        out = out / 255.0
        out = out.astype(orig_dtype)
    else:
        if np.issubdtype(orig_dtype, np.integer):
            out = np.clip(out, 0, 255).round().astype(orig_dtype)
        else:
            out = out.astype(orig_dtype)

    if verbose:
        print("DEBUG: out.shape", out.shape, "out.dtype", out.dtype,
              "min/max:", out.min(), out.max())
        if out.ndim == 3:
            print("DEBUG: channel means:", [out[...,c].mean() for c in range(out.shape[2])])

    return out

# %%
# # in ra ảnh sau khi dùng EDUMS
# img3 = edums_nhanh_ycbcr(img2, alpha=1.5, sigma=1.5, bgr=True, verbose=True)
# cv2.imwrite(f'{nameImg}_edums.png', img3)

# %%
#Khử rung EICL
def phat_hien_canh_sobel(anh_kenh, scale=1.0):
    """
    Phát hiện cạnh bằng Sobel trên một kênh
    """
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]]) * scale
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]]) * scale
    
    gx = ndimage.convolve(anh_kenh, sobel_x, mode='reflect')
    gy = ndimage.convolve(anh_kenh, sobel_y, mode='reflect')
    
    edge_magnitude = np.sqrt(gx**2 + gy**2)
    edge_magnitude = edge_magnitude / (edge_magnitude.max() + 1e-10)
    
    return edge_magnitude


def tao_ban_do_trong_so(edge_map, nguong=0.1, sigma_expand=2.0):
    """
    Tạo bản đồ trọng số từ edge map
    Vùng gần cạnh có trọng số cao hơn (cần loại bỏ ringing nhiều hơn)
    """
    # Tạo binary edge map
    binary_edges = (edge_map > nguong).astype(float)
    
    # Mở rộng vùng cạnh bằng Gaussian
    weight_map = gaussian_filter(binary_edges, sigma=sigma_expand)
    weight_map = np.clip(weight_map, 0.0, 1.0)
    
    return weight_map


def eicl_mot_kenh(kenh, nguong_canh=0.08, sigma_smooth=1.2, alpha=0.5):
    """
    Áp dụng EICL lên một kênh ảnh (Y, hoặc R, G, B)
    
    Args:
        kenh: Kênh ảnh (0-255)
        nguong_canh: Ngưỡng phát hiện cạnh
        sigma_smooth: Độ mạnh làm mượt
        alpha: Cường độ loại bỏ ringing (0-1)
    
    Returns:
        Kênh đã xử lý
    """
    # Phát hiện cạnh
    edge_map = phat_hien_canh_sobel(kenh)
    
    # Tạo bản đồ trọng số
    weight_map = tao_ban_do_trong_so(edge_map, nguong=nguong_canh, sigma_expand=sigma_smooth * 1.5)
    
    # Làm mượt kênh
    kenh_muot = gaussian_filter(kenh, sigma=sigma_smooth)
    
    # Trộn: vùng có ringing (gần cạnh) sẽ được làm mượt nhiều hơn
    kenh_eicl = kenh * (1.0 - alpha * weight_map) + kenh_muot * (alpha * weight_map)
    
    return kenh_eicl, edge_map, weight_map


def eicl_sau_edums(anh_edums, nguong_canh=0.08, sigma_smooth=1.2, alpha=0.5, 
                   bgr=False, verbose=False):
    """
    Áp dụng EICL để loại bỏ ringing artifacts sau khi sharpen bằng EDUMS.
    Xử lý trên không gian YCbCr, chỉ làm mượt kênh Y để giữ màu sắc.
    
    Args:
        anh_edums: Ảnh output từ EDUMS
        nguong_canh: Ngưỡng phát hiện cạnh (0.05-0.15 tốt)
        sigma_smooth: Độ mạnh làm mượt (1.0-2.0 tốt)
        alpha: Cường độ loại bỏ ringing (0.3-0.7 tốt)
        bgr: True nếu input là BGR (OpenCV)
        verbose: In thông tin debug
    
    Returns:
        Ảnh đã loại bỏ ringing, cùng dtype/scale với input
    """
    orig_dtype = anh_edums.dtype
    arr = anh_edums.astype(np.float64)
    
    # Kiểm tra scale 0-1
    scaled_from_0_1 = False
    if np.issubdtype(orig_dtype, np.floating) and arr.max() <= 1.0 + 1e-12:
        arr = arr * 255.0
        scaled_from_0_1 = True
    
    # Xử lý alpha channel
    has_alpha = (arr.ndim == 3 and arr.shape[2] == 4)
    alpha_chan = None
    if has_alpha:
        alpha_chan = arr[..., 3].copy()
        arr = arr[..., :3]
    
    if verbose:
        print(f"EICL: shape={arr.shape}, dtype={orig_dtype}, scaled_0_1={scaled_from_0_1}")
    
    # Xử lý ảnh xám
    if arr.ndim == 2:
        Y_eicl, edge_map, weight_map = eicl_mot_kenh(arr, nguong_canh, sigma_smooth, alpha)
        out = np.clip(Y_eicl, 0.0, 255.0)
        
    # Xử lý ảnh màu
    else:
        rgb = arr.copy()
        if bgr:
            rgb = rgb[..., ::-1]  # BGR -> RGB
        
        # Chuyển sang YCbCr
        Y, Cb, Cr = rgb_to_ycbcr_fullrange(rgb)
        
        # Chỉ áp dụng EICL lên kênh Y (giữ nguyên Cb, Cr)
        Y_eicl, edge_map, weight_map = eicl_mot_kenh(Y, nguong_canh, sigma_smooth, alpha)
        Y_eicl = np.clip(Y_eicl, 0.0, 255.0)
        
        # Chuyển ngược về RGB
        out_rgb = ycbcr_to_rgb_fullrange(Y_eicl, Cb, Cr)
        out_rgb = np.clip(out_rgb, 0.0, 255.0)
        
        if bgr:
            out_rgb = out_rgb[..., ::-1]  # RGB -> BGR
        
        out = out_rgb
    
    # Gắn lại alpha channel
    if has_alpha:
        out = np.concatenate([out, alpha_chan[..., np.newaxis]], axis=2)
    
    # Chuyển về dtype/scale gốc
    if scaled_from_0_1:
        out = out / 255.0
        out = out.astype(orig_dtype)
    else:
        if np.issubdtype(orig_dtype, np.integer):
            out = np.clip(out, 0, 255).round().astype(orig_dtype)
        else:
            out = out.astype(orig_dtype)
    
    if verbose:
        print(f"EICL output: shape={out.shape}, dtype={out.dtype}, range=[{out.min():.2f}, {out.max():.2f}]")
    
    return out

# %%
# img4 = eicl_sau_edums(img3, nguong_canh=0.08, sigma_smooth=1.2, alpha=0.5, bgr=True, verbose=True)
# cv2.imwrite(f'{nameImg}_eicl.png', img4)

# %%
# # đánh giá chất lượng ảnh
# ## chỉ sử dụng trong trường hợp 2 ảnh có cùng kích thước
# # Use the original upscaled image for comparison
# img5 = img1  # Original bicubic upscaled image
# img6 = img4  # EIAAF processed image

# # Convert img3 (single channel output) to 3-channel for comparison if needed
# # Ensure both images have the same shape for comparison
# if img5.shape != img6.shape:
# 	img6 = cv2.cvtColor(img6.astype(np.uint8), cv2.COLOR_GRAY2BGR)

# # Tính các chỉ số
# psnr_value = psnr(img5, img6)
# ssim_value = ssim(img5, img6, channel_axis=-1)
# mse_value = mse(img5, img6)
# rms_value = np.sqrt(mse_value)

# print(f"PSNR: {psnr_value}")
# print(f"SSIM: {ssim_value}")
# print(f"MSE: {mse_value}")
# print(f"RMS: {rms_value}")

# %%
# so sánh thông số và ghi vào file (so sánh 2 ảnh có kích thước khác nhau)
def compare_images_2(img1_path, img2_path, nameImg, output_file='comparison_results.txt'):
    """So sánh các thông số của 2 ảnh có kích thước khác nhau và ghi vào file"""
    
    # Mở file để ghi (mode 'a' để append vào file sẵn có)
    with open(output_file, 'a', encoding='utf-8') as f:
        # Đọc ảnh
        img1 = img1_path
        img2 = img2_path
    
        # 1. So sánh kích thước gốc
        f.write(f"=== THÔNG SỐ CƠ BẢN ẢNH SỐ {nameImg}===\n")
        f.write(f"Ảnh 1 (Ảnh gốc): {img1.shape} (HxWxC)\n")
        f.write(f"Ảnh 2 (Ảnh qua xử lý): {img2.shape} (HxWxC)\n")
        f.write(f"Tỷ lệ kích thước: {img1.shape[0]/img2.shape[0]:.2f}x{img1.shape[1]/img2.shape[1]:.2f}\n")
        
        # 2. So sánh số lượng pixel
        pixels1 = img1.shape[0] * img1.shape[1]
        pixels2 = img2.shape[0] * img2.shape[1]
        f.write(f"\nSố pixel - Ảnh 1: {pixels1:,} | Ảnh 2: {pixels2:,}\n")
        
        # 3. So sánh giá trị trung bình màu sắc
        f.write("\n=== THÔNG SỐ MÀU SẮC ===\n")
        mean1 = np.mean(img1, axis=(0,1))
        mean2 = np.mean(img2, axis=(0,1))
        f.write(f"Giá trị TB (BGR) - Ảnh 1: {mean1}\n")
        f.write(f"Giá trị TB (BGR) - Ảnh 2: {mean2}\n")
        
        # 4. So sánh độ sáng
        brightness1 = np.mean(cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY))
        brightness2 = np.mean(cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY))
        f.write(f"Độ sáng TB - Ảnh 1: {brightness1:.2f} | Ảnh 2: {brightness2:.2f}\n")
        
        # 5. So sánh độ tương phản
        std1 = np.std(cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY))
        std2 = np.std(cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY))
        f.write(f"Độ tương phản - Ảnh 1: {std1:.2f} | Ảnh 2: {std2:.2f}\n")
        
        # 6. So sánh histogram
        f.write("\n=== SO SÁNH HISTOGRAM ===\n")
        hist1 = cv2.calcHist([img1], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
        hist2 = cv2.calcHist([img2], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
        hist1 = cv2.normalize(hist1, hist1).flatten()
        hist2 = cv2.normalize(hist2, hist2).flatten()
        hist_correlation = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
        f.write(f"Tương quan histogram: {hist_correlation:.4f} (1 = giống nhất)\n")
        
        # 7. So sánh SSIM (cần resize về cùng kích thước)
        f.write("\n=== SO SÁNH NỘI DUNG (SSIM) ===\n")
        # Resize về kích thước nhỏ hơn để so sánh
        h = min(img1.shape[0], img2.shape[0])
        w = min(img1.shape[1], img2.shape[1])
        img1_resized = cv2.resize(img1, (w, h))
        img2_resized = cv2.resize(img2, (w, h))
        
        # Chuyển sang grayscale
        gray1 = cv2.cvtColor(img1_resized, cv2.COLOR_BGR2GRAY)
        gray2 = cv2.cvtColor(img2_resized, cv2.COLOR_BGR2GRAY)
        
        ssim_score = ssim(gray1, gray2)
        f.write(f"SSIM Score: {ssim_score:.4f} (1 = giống hệt)\n")
        
        # 8. So sánh MSE (Mean Squared Error)
        mse = np.mean((img1_resized.astype(float) - img2_resized.astype(float)) ** 2)
        f.write(f"MSE: {mse:.2f} (0 = giống hệt)\n")
        
        # 9. Tính PSNR
        if mse > 0:
            psnr = 20 * np.log10(255.0 / np.sqrt(mse))
            f.write(f"PSNR: {psnr:.2f} dB (>40 = rất giống)\n")
        f.write("=" * 40)
        f.write("\n")
        
    print(f"✓ Kết quả đã được ghi vào file: {output_file}")

# %%
# compare_images_2(img, img4, nameImg, output_file='Thong_so_co_ban.txt')

# %%
for i in range(1, 1255):
    #phương pháp bicubic"
    nameImg = f"{i}"
    img = cv2.imread(f"Dataset/{nameImg}.jpg")

    # resize bằng bicubic
    bicubic = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    img1 = bicubic
    cv2.imwrite(f"Output/{nameImg}_bicubic.jpg", img1)

    # EIAAF
    gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    # tính gradient
    gx = cv2.Sobel(gray, cv2.CV_32F, 1, 0)
    gy = cv2.Sobel(gray, cv2.CV_32F, 0, 1)

    mag = cv2.magnitude(gx, gy)
    dir = cv2.phase(gx, gy)

    # mờ theo hướng cạnh
    blur1 = cv2.GaussianBlur(img1, (5, 5), 0.5)
    mask = cv2.normalize(mag, None, 0, 1, cv2.NORM_MINMAX)

    # trộn
    mask = np.stack([mask] * 3, axis=-1)
    jaggy_suppressed = img1*(1-mask) + blur1*mask
    jaggy_suppressed = jaggy_suppressed.astype(np.uint8)
    img2 = jaggy_suppressed
    cv2.imwrite(f"Output/{nameImg}_EIAAF.jpg", img2)

    # in ra ảnh sau khi dùng EDUMS
    img3 = edums_nhanh_ycbcr(img2, alpha=1.5, sigma=1.5, bgr=True, verbose=True)
    cv2.imwrite(f'Output/{nameImg}_edums.png', img3)

    #Khử rung EICL
    img4 = eicl_sau_edums(img3, nguong_canh=0.08, sigma_smooth=1.2, alpha=0.5, bgr=True, verbose=True)
    cv2.imwrite(f'Output/{nameImg}_eicl.png', img4)

    # so sánh thông số và ghi vào file (so sánh 2 ảnh có kích thước khác nhau)
    compare_images_2(img, img4, nameImg, output_file='Thong_so_co_ban.txt')
# Out:
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [28.460892708333333, 59.975819791666666, 47.18426432291667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [181.80270364583333, 186.08129583333334, 190.7911359375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[12.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [23.44369348958333, 25.618552604166666, 41.030151822916665]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [79.90932760416666, 78.8806, 88.36125078125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [95.52766770833334, 133.34876119791667, 173.34437786458332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[4.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [204.82405026041667, 204.82405026041667, 204.82405026041667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 240.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [107.55629322916667, 98.50164140625, 129.582878125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [154.57879270833334, 145.15613541666667, 140.39119166666666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [93.87503697916667, 103.03846666666666, 107.90817369791667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [185.15733203125, 179.34974973958333, 171.4932515625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [101.814467042136, 103.69641687526074, 102.09649353358364]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [178.15745442708334, 179.94935182291667, 174.8734796875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[7.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [115.024875, 125.90450651041667, 128.94069322916667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [30.41117265625, 21.62841875, 22.87822161458333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 245.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [41.48845416666666, 117.48134973958334, 117.63312734375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [90.60576979166666, 87.90118802083333, 102.64682604166667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [46.95617369791667, 32.88379609375, 52.50081197916667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [45.027163020833335, 64.92223541666667, 66.08848151041667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[4.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [153.40456244778613, 153.1875096595656, 163.89139672096908]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[1.00, 249.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [125.54264619883041, 119.48789630325814, 120.76811351294904]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [116.16212755421185, 115.81723311092577, 113.54300510842369]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [184.84924114583333, 180.859740625, 159.46265911458335]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [169.96849577596996, 169.83130214851897, 163.56720875052147]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 242
# DEBUG: channel means: [29.03110390625, 33.60300859375, 37.147203645833336]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[3.00, 211.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [82.04160026041667, 76.52449765625, 63.96349296875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [53.154264920701166, 51.84455890025042, 52.072272537562604]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [154.32715260416666, 168.05335546875, 188.365609375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[14.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [120.22450699081803, 120.22450699081803, 120.22450699081803]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [73.49315677083334, 84.89415260416666, 94.34055703125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [74.34591588541667, 148.32483125, 169.2741859375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [90.72075, 99.413678125, 124.66903359375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [73.59663120567376, 65.64894216729245, 59.00651387150605]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [152.06826276041667, 154.60869322916668, 154.09831223958332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[5.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [85.6125328672788, 66.69246035058431, 152.92361513981635]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [185.52277604166667, 179.67555182291667, 175.06655]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[8.00, 252.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [179.77588072916666, 180.00618463541667, 191.3944390625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [124.39855739157632, 115.53464944745622, 82.64915711009175]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [40.94399947916666, 44.9837015625, 52.030162760416665]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[1.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [160.92936901041668, 158.33471380208334, 159.24615677083332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [128.32477473958335, 140.27155833333333, 151.12862630208335]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[4.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 243
# DEBUG: channel means: [143.74035338541665, 127.53044739583333, 115.09931640625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 243.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 244
# DEBUG: channel means: [101.56005338541667, 107.50874348958334, 102.64562630208333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 240.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [179.17934969741236, 176.9566681448247, 179.57470445534224]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[4.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [8.68299728940784, 35.74725969557965, 95.50638943911594]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 250
# DEBUG: channel means: [82.35213177083334, 83.92288307291666, 85.46265885416666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[1.00, 245.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [210.27715729166667, 212.03800598958333, 196.56428020833334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [116.46670022954925, 126.1465870200334, 132.76724306135225]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[2.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [209.93179231010018, 191.70353271076794, 171.49004982262105]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [39.84833671875, 34.288065625, 26.002990625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [200.67857838541667, 190.57378203125, 207.12144973958334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [51.78846669099249, 61.33120178273561, 63.08775516055046]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [98.24749921679198, 93.10402046783626, 117.29540935672514]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [79.13034951000834, 75.73866946413678, 59.614323394495415]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 251
# DEBUG: channel means: [184.18090130208333, 156.01684036458335, 122.6553796875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 242.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 225
# DEBUG: channel means: [66.7976015625, 70.54746171875, 74.122615625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[3.00, 225.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [132.2950096515025, 102.17644407345576, 62.20808065525876]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [126.40243385416667, 136.72021197916666, 145.20709348958334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [85.44926822916666, 89.04862994791667, 90.15890807291666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [156.99486450501254, 149.89142335004178, 145.32722378863826]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [83.22856620718463, 120.54327824770259, 124.77565189014202]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [120.88798932291667, 124.32673697916667, 121.14144192708333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[2.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [94.9704421875, 94.33188463541667, 118.91502369791667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [130.27377786458334, 127.13971744791667, 118.81010078125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[11.00, 245.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [154.70322291666668, 145.09400807291667, 108.67647578125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 248.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [74.50343645833334, 73.38225546875, 62.94963984375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 243.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [134.30521510416668, 134.50998463541666, 126.72671510416667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 17 255
# DEBUG: channel means: [106.39080703125, 106.199634375, 97.28495338541667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[28.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [134.38100755208333, 124.68806796875, 103.29705442708334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [30.88505859375, 31.389151302083334, 40.871715625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [104.59295572916666, 107.12402395833334, 112.68072942708334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[3.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [133.6263627819549, 140.51900167084378, 144.91057826858813]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[1.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [87.83866822916667, 92.708415625, 97.5291765625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [167.15108619791667, 167.6778890625, 164.12592708333332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 244
# DEBUG: channel means: [135.82301927083333, 138.58431223958334, 134.74082161458333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[2.00, 244.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [24.340682291666667, 88.059696875, 53.40343046875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [56.995876822916664, 55.21148072916667, 130.88422447916668]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[9.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [84.072075, 52.0231734375, 36.414126822916664]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2394, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2394, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [128.303373015873, 138.11688230994153, 126.95855002088555]
# EICL: shape=(1600, 2394, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2394, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [68.74946413678065, 38.965820736030025, 51.36625547331109]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[0.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [155.26608125, 153.2197765625, 155.13700598958334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[6.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 117
# DEBUG: channel means: [17.824549739583333, 24.165839322916668, 34.38902265625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 109.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [168.39973769294951, 133.98724786191073, 47.76536842928661]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [36.16645520833333, 38.512651302083334, 36.27536953125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[3.00, 242.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [175.83960052083333, 182.30325703125, 188.51085260416667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 238
# DEBUG: channel means: [139.93032786458335, 40.14707734375, 32.32045677083333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 235.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [55.93027864583333, 70.28062708333333, 76.85182604166667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [142.56686796875, 141.4400015625, 128.74147135416666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [179.71633125, 184.41427734375, 173.47412161458334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [135.89083359375, 124.71183333333333, 109.75001067708334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [64.46285546875, 80.60142864583334, 74.8806609375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [85.68620182291667, 88.93879765625, 80.91537786458333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [58.514910416666666, 66.94655807291667, 91.75094947916666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2398, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2398, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [50.85488401793161, 58.41279712260217, 63.56594349457882]
# EICL: shape=(1600, 2398, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2398, 3), dtype=uint8, range=[2.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [59.964603385416666, 92.01930052083334, 128.02148255208334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 254
# DEBUG: channel means: [113.63749973925741, 113.63749973925741, 113.63749973925741]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 227.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [37.81609921875, 34.587252864583334, 21.3799546875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 240
# DEBUG: channel means: [143.88964453125, 103.9766984375, 84.61262682291667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 240.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [124.5792046875, 147.487853125, 182.22749739583332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 248.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [113.03153012740184, 113.03153012740184, 113.03153012740184]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 197
# DEBUG: channel means: [2.60341640625, 2.6268161458333332, 2.638800520833333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 181.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [88.84380494791667, 106.7188625, 124.83954869791667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[1.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 253
# DEBUG: channel means: [80.68269296875, 85.7836625, 85.79761276041667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 246.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [170.29588046875, 165.18494921875, 141.420090625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [205.00252890625, 188.11770729166668, 179.679984375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[5.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [2.266013802083333, 5.942854947916667, 23.617451822916667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [106.32218229166666, 110.813825, 103.06011848958333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [41.610378645833336, 112.48953072916666, 167.57091119791667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [93.60960442708334, 99.49172760416667, 113.97432109375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[10.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 220
# DEBUG: channel means: [77.44153838130997, 95.01266531080518, 110.29938751564455]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 219.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [124.49878072916667, 129.79177395833332, 141.39590833333332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[3.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [169.45036927083333, 184.47120390625, 217.42440963541668]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [64.42999060150376, 91.35853827276524, 109.04304746240601]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [206.66198932291667, 216.14307213541667, 225.63059453125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[1.00, 248.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [53.97228619791667, 45.22274505208333, 38.4774703125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 237
# DEBUG: channel means: [28.486869791666667, 28.549621354166668, 17.90210234375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 231.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [25.862836458333334, 52.10966354166667, 94.83034322916667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [46.38598776041667, 43.651396354166664, 45.122475260416664]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [169.93112395833333, 179.36889973958333, 183.59922369791667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 245.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [202.78631666666666, 208.58962447916667, 203.42411640625]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [21.259942447916668, 37.77556588541667, 22.855410677083334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [4.598816666666667, 30.082821354166665, 8.379373697916666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [42.40639765625, 27.907926822916668, 2.3723419270833332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [3.30320847245409, 22.514479862270452, 28.15044736018364]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# ...
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 229
# DEBUG: channel means: [53.39831041666667, 61.25176979166667, 114.44809973958333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 229.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [32.11085338541667, 24.4703109375, 23.998120572916665]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 252.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [124.72795677083333, 103.28454296875, 105.30951536458333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 2 255
# DEBUG: channel means: [100.69839494569757, 98.92357247284879, 111.10751461988303]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[16.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [87.21441207184628, 116.02034095655806, 107.74742846700083]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [148.7691796875, 148.74664713541668, 146.94635833333334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[5.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [71.9568421875, 70.76577552083333, 71.2406484375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [148.46884401041666, 140.388575, 131.7425]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [99.49564791666667, 65.22938984375, 29.125450520833333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 253.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [45.405405989583336, 73.83640052083334, 72.81180989583333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [89.22472708333333, 144.32334583333332, 128.97177369791666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [65.13999609375, 70.91936770833334, 72.93833723958333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [40.75487421875, 56.750266145833336, 113.47153463541666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [51.81229836185309, 117.40573090567612, 72.06378495409015]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2396, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2396, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [76.25639451168614, 46.41404632721202, 40.38606922996661]
# EICL: shape=(1600, 2396, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2396, 3), dtype=uint8, range=[0.00, 252.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [43.48521953125, 60.04263828125, 49.70144557291667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 242.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [120.53825104166667, 139.02664114583334, 161.54314739583333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[4.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [72.83906680225282, 60.56115847934919, 44.904909522319564]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [243.186071875, 165.40096614583334, 82.007753125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [80.68681502920317, 75.98817010846892, 72.12353645181477]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 248.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [94.17688229166667, 91.41489010416667, 97.06982942708333]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[2.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [129.30911640625, 150.89901197916666, 156.27396822916666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [73.56149453125, 157.514159375, 127.07932734375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 250
# DEBUG: channel means: [63.86187291666667, 27.209905208333332, 34.363785416666666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 250.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [86.563675, 93.75599244791667, 122.38150260416667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [28.40716822916667, 22.242988020833334, 9.969558072916668]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 32 255
# DEBUG: channel means: [237.25204939431913, 228.23428258145364, 203.68645206766917]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[41.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [88.06414160401002, 47.560592105263154, 80.29804720133667]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 240.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [116.23860390625, 139.22791796875, 154.73755260416667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [227.04201475803086, 219.54492986024198, 214.85693862119317]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[3.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 252
# DEBUG: channel means: [187.8090640625, 188.331509375, 184.74327421875]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 251.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [91.680778125, 118.00322682291667, 128.26050520833334]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 201
# DEBUG: channel means: [100.31179765625, 83.67962473958333, 30.359266666666667]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[1.00, 199.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1596, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1596, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [64.42461779448621, 64.42461779448621, 64.42461779448621]
# EICL: shape=(1596, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1596, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [9.089601302083333, 11.429853125, 53.29813125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 48 255
# DEBUG: channel means: [209.43113411458333, 225.621771875, 253.00072057291666]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[51.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [98.19363723958334, 101.64878333333333, 112.14084375]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1598, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1598, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [102.47496949311639, 110.69022658531497, 118.1847642886942]
# EICL: shape=(1598, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1598, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [164.7218, 167.30605130208335, 170.60719583333332]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 255.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 0 255
# DEBUG: channel means: [88.20340494791667, 99.25441458333333, 105.82745703125]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[0.00, 254.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
# DEBUG: arr.shape (1600, 2400, 3) dtype uint8 scaled_from_0_1 False
# DEBUG: out.shape (1600, 2400, 3) out.dtype uint8 min/max: 10 251
# DEBUG: channel means: [56.3016609375, 91.40282578125, 149.08568776041668]
# EICL: shape=(1600, 2400, 3), dtype=uint8, scaled_0_1=False
# EICL output: shape=(1600, 2400, 3), dtype=uint8, range=[10.00, 247.00]
# ✓ Kết quả đã được ghi vào file: Thong_so_co_ban.txt
